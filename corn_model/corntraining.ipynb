# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D,Activation,LeakyReLU,BatchNormalization,MaxPooling2D,Flatten,Dense,Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K


from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,img_to_array
#import xgboost as xgb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.11.0-cp39-cp39-win_amd64.whl (1.9 kB)
# Collecting tensorflow-intel==2.11.0
#   Downloading tensorflow_intel-2.11.0-cp39-cp39-win_amd64.whl (266.3 MB)
# Requirement already satisfied: packaging in c:\users\furta\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (21.3)
# Collecting tensorflow-estimator<2.12,>=2.11.0
#   Using cached tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
# Requirement already satisfied: six>=1.12.0 in c:\users\furta\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\furta\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.4.0)
# Collecting tensorboard<2.12,>=2.11
#   Using cached tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\furta\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.12.1)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-2.2.0-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\furta\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.6.0)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\furta\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.42.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\furta\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.21.5)
# Collecting libclang>=13.0.0
#   Using cached libclang-15.0.6.1-py2.py3-none-win_amd64.whl (23.2 MB)
# Collecting keras<2.12,>=2.11.0
#   Using cached keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\furta\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (23.1.4)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\furta\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.1)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.30.0-cp39-cp39-win_amd64.whl (1.5 MB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\furta\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.1.1)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: setuptools in c:\users\furta\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (61.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\furta\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.37.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\furta\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.3)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\furta\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.27.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\furta\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.33.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\furta\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3.4)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\furta\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\furta\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\furta\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.2.2)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\furta\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\furta\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\furta\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\furta\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\furta\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.9)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\furta\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.11.0->tensorflow) (3.0.4)
# Installing collected packages: oauthlib, requests-oauthlib, tensorboard-plugin-wit, tensorboard-data-server, google-auth-oauthlib, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, opt-einsum, libclang, keras, google-pasta, gast, astunparse, tensorflow-intel, tensorflow
# Successfully installed astunparse-1.6.3 gast-0.4.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 keras-2.11.0 libclang-15.0.6.1 oauthlib-3.2.2 opt-einsum-3.3.0 requests-oauthlib-1.3.1 tensorboard-2.11.2 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.11.0 tensorflow-estimator-2.11.0 tensorflow-intel-2.11.0 tensorflow-io-gcs-filesystem-0.30.0 termcolor-2.2.0

# %%
import pickle
import cv2
import os
from os import listdir
from sklearn.preprocessing import LabelBinarizer,MultiLabelBinarizer
from sklearn.model_selection import train_test_split

# %%
root_dir = r'C:\ashlin\college study material\1_CodeMob\corn_model\Data_Corn'

os.chdir(root_dir)
listdir()
# Out:
# ['Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot',
#  'Corn_(maize)___Common_rust_',
#  'Corn_(maize)___healthy',
#  'Corn_(maize)___Northern_Leaf_Blight']

# %%
DEFAULT_IMAGE_SIZE = tuple((256, 256))

# Number of images used to train the model
N_IMAGES = 100

data_dir = os.path.join(root_dir,'train')
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None:
            image = cv2.resize(image, DEFAULT_IMAGE_SIZE)   
            return img_to_array(image)
        else:
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
plant_disease_folder_list = listdir(data_dir)
print(len(plant_disease_folder_list))
# Out:
# 4

# %%
image_list, label_list = [], []

try:
    print("Loading Image Data ...")
    for s in listdir():
        print(s)
        plant_disease_folder_list = listdir(s)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"Processing  {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{data_dir}/{plant_disease_folder}/")

            for image in plant_disease_image_list[:N_IMAGES]:
                image_directory = f"{data_dir}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg")==True or image_directory.endswith(".JPG")==True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)

    print("All the images have successfully loaded!!")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# Loading Image Data ...
# train
# Processing  Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot ...
# Processing  Corn_(maize)___Common_rust_ ...
# Processing  Corn_(maize)___healthy ...
# Processing  Corn_(maize)___Northern_Leaf_Blight ...
# All the images have successfully loaded!!

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 255.0

# Check the number of images loaded for training
image_len = len(image_list)
print(f"Total number of images: {image_len}")
# Out:
# Total number of images: 400

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)

# pickle.dump(label_binarizer,open('plant_disease_label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

print("Total number of classes: ", n_classes)
# Out:
# Total number of classes:  4

# %%
augment = ImageDataGenerator(rotation_range=25, width_shift_range=0.1,
                             height_shift_range=0.1, shear_range=0.2, 
                             zoom_range=0.2, horizontal_flip=True, 
                             fill_mode="nearest")

# %%
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
print('Successfully split data into TRAIN & TEST')
# Out:
# Successfully split data into TRAIN & TEST

# %%
EPOCHS = 10
STEPS = 100
LR = 1e-3
BATCH_SIZE = 32
WIDTH = 256
HEIGHT = 256
DEPTH = 3
model = Sequential()
inputShape = (HEIGHT, WIDTH, DEPTH)
chanDim = -1

if K.image_data_format() == "channels_first":
    inputShape = (DEPTH, HEIGHT, WIDTH)
    chanDim = 1

model.add(Conv2D(32, (3, 3), padding="same",input_shape=inputShape))
model.add(LeakyReLU(alpha=0.1))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding="same"))
model.add(LeakyReLU(alpha=0.1))
model.add(BatchNormalization(axis=chanDim))

model.add(Conv2D(64, (3, 3), padding="same"))
model.add(LeakyReLU(alpha=0.1))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), padding="same"))
model.add(LeakyReLU(alpha=0.1))
model.add(BatchNormalization(axis=chanDim))

model.add(Conv2D(128, (3, 3), padding="same"))
model.add(LeakyReLU(alpha=0.1))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(1024, name = 'my_dense'))
model.add(LeakyReLU(alpha=0.1))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(n_classes))
model.add(Activation("softmax"))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 256, 256, 32)      896
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 256, 256, 32)      0
#
#  batch_normalization_6 (Batc  (None, 256, 256, 32)     128
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 85, 85, 32)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 85, 85, 32)        0
#
#  conv2d_6 (Conv2D)           (None, 85, 85, 64)        18496
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 85, 85, 64)        0
#
#  batch_normalization_7 (Batc  (None, 85, 85, 64)       256
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 85, 85, 64)        36928
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 85, 85, 64)        0
#
#  batch_normalization_8 (Batc  (None, 85, 85, 64)       256
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 42, 42, 64)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 42, 42, 64)        0
#
#  conv2d_8 (Conv2D)           (None, 42, 42, 128)       73856
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 42, 42, 128)       0
#
#  batch_normalization_9 (Batc  (None, 42, 42, 128)      512
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 42, 42, 128)       147584
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 42, 42, 128)       0
#
#  batch_normalization_10 (Bat  (None, 42, 42, 128)      512
#  chNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 21, 21, 128)      0
#  2D)
#
#  dropout_6 (Dropout)         (None, 21, 21, 128)       0
#
#  flatten_1 (Flatten)         (None, 56448)             0
#
#  my_dense (Dense)            (None, 1024)              57803776
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 1024)              0
#
#  batch_normalization_11 (Bat  (None, 1024)             4096
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 4)                 4100
#
#  activation_1 (Activation)   (None, 4)                 0
#
# =================================================================
# Total params: 58,091,396
# Trainable params: 58,088,516
# Non-trainable params: 2,880
# _________________________________________________________________

# %%
# opt = Adam(learning_rate=LR, decay=LR / EPOCHS)
import tensorflow as tf
import keras
# Compile model
model.compile('adam', loss=tf.keras.losses.BinaryCrossentropy(), metrics=['accuracy'])

# Train model
print("Training CNN...")
history = model.fit(augment.flow(x_train, y_train, batch_size=BATCH_SIZE),
                              validation_data=(x_test, y_test),
                              epochs=200, 
                              verbose=1)
        
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# Training CNN...
# Epoch 1/200
# 10/10 [==============================] - 43s 4s/step - loss: 0.2783 - accuracy: 0.8687 - val_loss: 1.0138 - val_accuracy: 0.2250
# Epoch 2/200
# 10/10 [==============================] - 36s 4s/step - loss: 0.2587 - accuracy: 0.8438 - val_loss: 0.8775 - val_accuracy: 0.2250
# Epoch 3/200
# 10/10 [==============================] - 37s 4s/step - loss: 0.1602 - accuracy: 0.9187 - val_loss: 1.4151 - val_accuracy: 0.2250
# Epoch 4/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.1021 - accuracy: 0.9438 - val_loss: 2.5344 - val_accuracy: 0.2250
# Epoch 5/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0964 - accuracy: 0.9500 - val_loss: 2.7368 - val_accuracy: 0.2250
# Epoch 6/200
# 10/10 [==============================] - 32s 3s/step - loss: 0.1011 - accuracy: 0.9469 - val_loss: 1.6947 - val_accuracy: 0.2250
# Epoch 7/200
# 10/10 [==============================] - 32s 3s/step - loss: 0.0989 - accuracy: 0.9312 - val_loss: 1.3443 - val_accuracy: 0.2250
# Epoch 8/200
# 10/10 [==============================] - 32s 3s/step - loss: 0.0746 - accuracy: 0.9656 - val_loss: 1.2472 - val_accuracy: 0.2500
# Epoch 9/200
# 10/10 [==============================] - 32s 3s/step - loss: 0.0775 - accuracy: 0.9563 - val_loss: 1.9522 - val_accuracy: 0.2250
# Epoch 10/200
# 10/10 [==============================] - 38s 4s/step - loss: 0.0762 - accuracy: 0.9719 - val_loss: 2.0352 - val_accuracy: 0.2250
# Epoch 11/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0799 - accuracy: 0.9531 - val_loss: 0.7862 - val_accuracy: 0.2250
# Epoch 12/200
# 10/10 [==============================] - 32s 3s/step - loss: 0.0539 - accuracy: 0.9688 - val_loss: 1.6941 - val_accuracy: 0.2250
# Epoch 13/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0814 - accuracy: 0.9563 - val_loss: 1.8689 - val_accuracy: 0.2250
# Epoch 14/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0566 - accuracy: 0.9656 - val_loss: 1.3561 - val_accuracy: 0.2625
# Epoch 15/200
# 10/10 [==============================] - 32s 3s/step - loss: 0.0648 - accuracy: 0.9563 - val_loss: 1.2211 - val_accuracy: 0.2250
# Epoch 16/200
# 10/10 [==============================] - 30s 3s/step - loss: 0.0721 - accuracy: 0.9594 - val_loss: 1.7180 - val_accuracy: 0.2250
# Epoch 17/200
# 10/10 [==============================] - 31s 3s/step - loss: 0.0905 - accuracy: 0.9438 - val_loss: 0.6888 - val_accuracy: 0.4250
# Epoch 18/200
# 10/10 [==============================] - 30s 3s/step - loss: 0.0718 - accuracy: 0.9594 - val_loss: 1.0793 - val_accuracy: 0.2875
# Epoch 19/200
# 10/10 [==============================] - 30s 3s/step - loss: 0.0701 - accuracy: 0.9625 - val_loss: 0.7131 - val_accuracy: 0.4750
# Epoch 20/200
# 10/10 [==============================] - 32s 3s/step - loss: 0.0622 - accuracy: 0.9625 - val_loss: 1.4083 - val_accuracy: 0.2250
# Epoch 21/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.1087 - accuracy: 0.9312 - val_loss: 0.4635 - val_accuracy: 0.5750
# Epoch 22/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0604 - accuracy: 0.9719 - val_loss: 1.9018 - val_accuracy: 0.2625
# Epoch 23/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0384 - accuracy: 0.9875 - val_loss: 2.1695 - val_accuracy: 0.2625
# Epoch 24/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0387 - accuracy: 0.9781 - val_loss: 1.3654 - val_accuracy: 0.3375
# Epoch 25/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0409 - accuracy: 0.9719 - val_loss: 1.8023 - val_accuracy: 0.2625
# Epoch 26/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0420 - accuracy: 0.9781 - val_loss: 2.3680 - val_accuracy: 0.2875
# Epoch 27/200
# 10/10 [==============================] - 32s 3s/step - loss: 0.0345 - accuracy: 0.9844 - val_loss: 0.9896 - val_accuracy: 0.3375
# Epoch 28/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0315 - accuracy: 0.9844 - val_loss: 0.8630 - val_accuracy: 0.4625
# Epoch 29/200
# 10/10 [==============================] - 36s 4s/step - loss: 0.0482 - accuracy: 0.9688 - val_loss: 0.4521 - val_accuracy: 0.6125
# Epoch 30/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0595 - accuracy: 0.9563 - val_loss: 0.5644 - val_accuracy: 0.5250
# Epoch 31/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0414 - accuracy: 0.9781 - val_loss: 0.6023 - val_accuracy: 0.5625
# Epoch 32/200
# 10/10 [==============================] - 37s 4s/step - loss: 0.0428 - accuracy: 0.9812 - val_loss: 0.3431 - val_accuracy: 0.7250
# Epoch 33/200
# 10/10 [==============================] - 39s 4s/step - loss: 0.0379 - accuracy: 0.9781 - val_loss: 0.4655 - val_accuracy: 0.6375
# Epoch 34/200
# 10/10 [==============================] - 36s 3s/step - loss: 0.0348 - accuracy: 0.9781 - val_loss: 0.4615 - val_accuracy: 0.6375
# Epoch 35/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0197 - accuracy: 0.9937 - val_loss: 0.5677 - val_accuracy: 0.5750
# Epoch 36/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0132 - accuracy: 0.9969 - val_loss: 0.4141 - val_accuracy: 0.6750
# Epoch 37/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0235 - accuracy: 0.9875 - val_loss: 0.6350 - val_accuracy: 0.5500
# Epoch 38/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0183 - accuracy: 0.9969 - val_loss: 0.7575 - val_accuracy: 0.5125
# Epoch 39/200
# 10/10 [==============================] - 36s 4s/step - loss: 0.0208 - accuracy: 0.9875 - val_loss: 0.2390 - val_accuracy: 0.8375
# Epoch 40/200
# 10/10 [==============================] - 36s 4s/step - loss: 0.0899 - accuracy: 0.9688 - val_loss: 1.5882 - val_accuracy: 0.3875
# Epoch 41/200
# 10/10 [==============================] - 36s 4s/step - loss: 0.0543 - accuracy: 0.9688 - val_loss: 0.3918 - val_accuracy: 0.7125
# Epoch 42/200
# 10/10 [==============================] - 38s 4s/step - loss: 0.0445 - accuracy: 0.9688 - val_loss: 0.2989 - val_accuracy: 0.7750
# Epoch 43/200
# 10/10 [==============================] - 39s 4s/step - loss: 0.0279 - accuracy: 0.9844 - val_loss: 0.3247 - val_accuracy: 0.7125
# Epoch 44/200
# 10/10 [==============================] - 37s 4s/step - loss: 0.0180 - accuracy: 0.9906 - val_loss: 0.6681 - val_accuracy: 0.6750
# Epoch 45/200
# 10/10 [==============================] - 36s 4s/step - loss: 0.0207 - accuracy: 0.9937 - val_loss: 0.4058 - val_accuracy: 0.6875
# Epoch 46/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0290 - accuracy: 0.9812 - val_loss: 0.8658 - val_accuracy: 0.6000
# Epoch 47/200
# 10/10 [==============================] - 39s 4s/step - loss: 0.0387 - accuracy: 0.9781 - val_loss: 0.5380 - val_accuracy: 0.6625
# Epoch 48/200
# 10/10 [==============================] - 40s 4s/step - loss: 0.0288 - accuracy: 0.9844 - val_loss: 0.0927 - val_accuracy: 0.9000
# Epoch 49/200
# 10/10 [==============================] - 40s 4s/step - loss: 0.0245 - accuracy: 0.9875 - val_loss: 0.1929 - val_accuracy: 0.8875
# Epoch 50/200
# 10/10 [==============================] - 39s 4s/step - loss: 0.0235 - accuracy: 0.9781 - val_loss: 0.1138 - val_accuracy: 0.9125
# Epoch 51/200
# 10/10 [==============================] - 38s 4s/step - loss: 0.0349 - accuracy: 0.9812 - val_loss: 0.5634 - val_accuracy: 0.7375
# Epoch 52/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0208 - accuracy: 0.9844 - val_loss: 0.3028 - val_accuracy: 0.8375
# Epoch 53/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0183 - accuracy: 0.9844 - val_loss: 0.3467 - val_accuracy: 0.8250
# Epoch 54/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0192 - accuracy: 0.9875 - val_loss: 0.3845 - val_accuracy: 0.8000
# Epoch 55/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0416 - accuracy: 0.9781 - val_loss: 0.1273 - val_accuracy: 0.9250
# Epoch 56/200
# 10/10 [==============================] - 37s 4s/step - loss: 0.0228 - accuracy: 0.9875 - val_loss: 0.1649 - val_accuracy: 0.8875
# Epoch 57/200
# 10/10 [==============================] - 32s 3s/step - loss: 0.0194 - accuracy: 0.9906 - val_loss: 0.0677 - val_accuracy: 0.9500
# Epoch 58/200
# 10/10 [==============================] - 31s 3s/step - loss: 0.0316 - accuracy: 0.9781 - val_loss: 0.4689 - val_accuracy: 0.7125
# Epoch 59/200
# 10/10 [==============================] - 31s 3s/step - loss: 0.0438 - accuracy: 0.9750 - val_loss: 1.0349 - val_accuracy: 0.5875
# Epoch 60/200
# 10/10 [==============================] - 31s 3s/step - loss: 0.0452 - accuracy: 0.9719 - val_loss: 0.2659 - val_accuracy: 0.9000
# Epoch 61/200
# 10/10 [==============================] - 31s 3s/step - loss: 0.0551 - accuracy: 0.9844 - val_loss: 0.3594 - val_accuracy: 0.8250
# Epoch 62/200
# 10/10 [==============================] - 31s 3s/step - loss: 0.0270 - accuracy: 0.9844 - val_loss: 0.6404 - val_accuracy: 0.7625
# Epoch 63/200
# 10/10 [==============================] - 31s 3s/step - loss: 0.0227 - accuracy: 0.9906 - val_loss: 0.3913 - val_accuracy: 0.8250
# Epoch 64/200
# 10/10 [==============================] - 31s 3s/step - loss: 0.0099 - accuracy: 0.9937 - val_loss: 0.1209 - val_accuracy: 0.9125
# Epoch 65/200
# 10/10 [==============================] - 31s 3s/step - loss: 0.0194 - accuracy: 0.9937 - val_loss: 0.0379 - val_accuracy: 0.9750
# Epoch 66/200
# 10/10 [==============================] - 32s 3s/step - loss: 0.0145 - accuracy: 0.9937 - val_loss: 0.0942 - val_accuracy: 0.9625
# Epoch 67/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0141 - accuracy: 0.9937 - val_loss: 0.0975 - val_accuracy: 0.9500
# Epoch 68/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0122 - accuracy: 0.9906 - val_loss: 0.2202 - val_accuracy: 0.9000
# Epoch 69/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0200 - accuracy: 0.9875 - val_loss: 0.2579 - val_accuracy: 0.8750
# Epoch 70/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0198 - accuracy: 0.9937 - val_loss: 0.3584 - val_accuracy: 0.8500
# Epoch 71/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0244 - accuracy: 0.9875 - val_loss: 0.0762 - val_accuracy: 0.9625
# Epoch 72/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0220 - accuracy: 0.9844 - val_loss: 0.0574 - val_accuracy: 0.9750
# Epoch 73/200
# 10/10 [==============================] - 36s 4s/step - loss: 0.0378 - accuracy: 0.9812 - val_loss: 0.1414 - val_accuracy: 0.9375
# Epoch 74/200
# 10/10 [==============================] - 36s 4s/step - loss: 0.0175 - accuracy: 0.9875 - val_loss: 0.0874 - val_accuracy: 0.9500
# Epoch 75/200
# 10/10 [==============================] - 37s 4s/step - loss: 0.0254 - accuracy: 0.9875 - val_loss: 0.2881 - val_accuracy: 0.8625
# Epoch 76/200
# 10/10 [==============================] - 38s 4s/step - loss: 0.0380 - accuracy: 0.9750 - val_loss: 0.0828 - val_accuracy: 0.9500
# Epoch 77/200
# 10/10 [==============================] - 39s 4s/step - loss: 0.0140 - accuracy: 0.9906 - val_loss: 0.0819 - val_accuracy: 0.9500
# Epoch 78/200
# 10/10 [==============================] - 37s 4s/step - loss: 0.0312 - accuracy: 0.9906 - val_loss: 0.5224 - val_accuracy: 0.7375
# Epoch 79/200
# 10/10 [==============================] - 37s 4s/step - loss: 0.0359 - accuracy: 0.9750 - val_loss: 0.2622 - val_accuracy: 0.8500
# Epoch 80/200
# 10/10 [==============================] - 38s 4s/step - loss: 0.0235 - accuracy: 0.9906 - val_loss: 0.2485 - val_accuracy: 0.8750
# Epoch 81/200
# 10/10 [==============================] - 44s 4s/step - loss: 0.0274 - accuracy: 0.9844 - val_loss: 0.0617 - val_accuracy: 0.9625
# Epoch 82/200
# 10/10 [==============================] - 38s 4s/step - loss: 0.0223 - accuracy: 0.9906 - val_loss: 0.0610 - val_accuracy: 0.9500
# Epoch 83/200
# 10/10 [==============================] - 37s 4s/step - loss: 0.0203 - accuracy: 0.9937 - val_loss: 0.1953 - val_accuracy: 0.8875
# Epoch 84/200
# 10/10 [==============================] - 36s 4s/step - loss: 0.0287 - accuracy: 0.9844 - val_loss: 0.1455 - val_accuracy: 0.9250
# Epoch 85/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0364 - accuracy: 0.9781 - val_loss: 0.3152 - val_accuracy: 0.8625
# Epoch 86/200
# 10/10 [==============================] - 35s 4s/step - loss: 0.0182 - accuracy: 0.9906 - val_loss: 0.1080 - val_accuracy: 0.9375
# Epoch 87/200
# 10/10 [==============================] - 38s 4s/step - loss: 0.0095 - accuracy: 0.9969 - val_loss: 0.0340 - val_accuracy: 0.9875
# Epoch 88/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0216 - accuracy: 0.9937 - val_loss: 0.0395 - val_accuracy: 0.9750
# Epoch 89/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0132 - accuracy: 0.9969 - val_loss: 0.1963 - val_accuracy: 0.8875
# Epoch 90/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0399 - accuracy: 0.9750 - val_loss: 0.3391 - val_accuracy: 0.8375
# Epoch 91/200
# 10/10 [==============================] - 36s 3s/step - loss: 0.0296 - accuracy: 0.9781 - val_loss: 1.1796 - val_accuracy: 0.7500
# Epoch 92/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0090 - accuracy: 0.9969 - val_loss: 1.6685 - val_accuracy: 0.6000
# Epoch 93/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0188 - accuracy: 0.9937 - val_loss: 0.8817 - val_accuracy: 0.6500
# Epoch 94/200
# 10/10 [==============================] - 40s 4s/step - loss: 0.0206 - accuracy: 0.9844 - val_loss: 0.3055 - val_accuracy: 0.7750
# Epoch 95/200
# 10/10 [==============================] - 38s 4s/step - loss: 0.0330 - accuracy: 0.9812 - val_loss: 0.3194 - val_accuracy: 0.8375
# Epoch 96/200
# 10/10 [==============================] - 40s 4s/step - loss: 0.0408 - accuracy: 0.9844 - val_loss: 0.4447 - val_accuracy: 0.7500
# Epoch 97/200
# 10/10 [==============================] - 37s 4s/step - loss: 0.0238 - accuracy: 0.9844 - val_loss: 1.2448 - val_accuracy: 0.5750
# Epoch 98/200
# 10/10 [==============================] - 37s 4s/step - loss: 0.0195 - accuracy: 0.9844 - val_loss: 0.6358 - val_accuracy: 0.7125
# Epoch 99/200
# 10/10 [==============================] - 37s 4s/step - loss: 0.0534 - accuracy: 0.9781 - val_loss: 0.1387 - val_accuracy: 0.9500
# Epoch 100/200
# 10/10 [==============================] - 37s 4s/step - loss: 0.0189 - accuracy: 0.9875 - val_loss: 0.3029 - val_accuracy: 0.8625
# Epoch 101/200
# 10/10 [==============================] - 37s 4s/step - loss: 0.0362 - accuracy: 0.9750 - val_loss: 0.1257 - val_accuracy: 0.9375
# Epoch 102/200
# 10/10 [==============================] - 38s 4s/step - loss: 0.0200 - accuracy: 0.9906 - val_loss: 0.0528 - val_accuracy: 0.9625
# Epoch 103/200
# 10/10 [==============================] - 39s 4s/step - loss: 0.0140 - accuracy: 0.9875 - val_loss: 0.0672 - val_accuracy: 0.9625
# Epoch 104/200
# 10/10 [==============================] - 43s 4s/step - loss: 0.0157 - accuracy: 0.9906 - val_loss: 0.1229 - val_accuracy: 0.9375
# Epoch 105/200
# 10/10 [==============================] - 38s 4s/step - loss: 0.0105 - accuracy: 0.9969 - val_loss: 0.0758 - val_accuracy: 0.9625
# Epoch 106/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0062 - accuracy: 0.9969 - val_loss: 0.0614 - val_accuracy: 0.9625
# Epoch 107/200
# 10/10 [==============================] - 37s 4s/step - loss: 0.0130 - accuracy: 0.9875 - val_loss: 0.0561 - val_accuracy: 0.9625
# Epoch 108/200
# 10/10 [==============================] - 37s 4s/step - loss: 0.0083 - accuracy: 0.9937 - val_loss: 0.1115 - val_accuracy: 0.9500
# Epoch 109/200
# 10/10 [==============================] - 42s 4s/step - loss: 0.0077 - accuracy: 0.9969 - val_loss: 0.2095 - val_accuracy: 0.8875
# Epoch 110/200
# 10/10 [==============================] - 47s 5s/step - loss: 0.0139 - accuracy: 0.9906 - val_loss: 0.3258 - val_accuracy: 0.8125
# Epoch 111/200
# 10/10 [==============================] - 47s 5s/step - loss: 0.0113 - accuracy: 0.9906 - val_loss: 0.2242 - val_accuracy: 0.8875
# Epoch 112/200
# 10/10 [==============================] - 40s 4s/step - loss: 0.0088 - accuracy: 0.9969 - val_loss: 0.3161 - val_accuracy: 0.8625
# Epoch 113/200
# 10/10 [==============================] - 38s 4s/step - loss: 0.0162 - accuracy: 0.9937 - val_loss: 0.3283 - val_accuracy: 0.8625
# Epoch 114/200
# 10/10 [==============================] - 43s 4s/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.1617 - val_accuracy: 0.9000
# Epoch 115/200
# 10/10 [==============================] - 43s 4s/step - loss: 0.0212 - accuracy: 0.9906 - val_loss: 0.2432 - val_accuracy: 0.8625
# Epoch 116/200
# 10/10 [==============================] - 46s 5s/step - loss: 0.0101 - accuracy: 0.9969 - val_loss: 0.7923 - val_accuracy: 0.7750
# Epoch 117/200
# 10/10 [==============================] - 44s 4s/step - loss: 0.0122 - accuracy: 0.9969 - val_loss: 0.1402 - val_accuracy: 0.9500
# Epoch 118/200
# 10/10 [==============================] - 41s 4s/step - loss: 0.0118 - accuracy: 0.9969 - val_loss: 0.1031 - val_accuracy: 0.9500
# Epoch 119/200
# 10/10 [==============================] - 37s 4s/step - loss: 0.0145 - accuracy: 0.9875 - val_loss: 0.6413 - val_accuracy: 0.7250
# Epoch 120/200
# 10/10 [==============================] - 37s 4s/step - loss: 0.0130 - accuracy: 0.9937 - val_loss: 0.9760 - val_accuracy: 0.6375
# Epoch 121/200
# 10/10 [==============================] - 36s 4s/step - loss: 0.0068 - accuracy: 0.9969 - val_loss: 0.1323 - val_accuracy: 0.9250
# Epoch 122/200
# 10/10 [==============================] - 40s 4s/step - loss: 0.0072 - accuracy: 0.9969 - val_loss: 0.0787 - val_accuracy: 0.9500
# Epoch 123/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0141 - accuracy: 0.9875 - val_loss: 0.2595 - val_accuracy: 0.8500
# Epoch 124/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0085 - accuracy: 0.9937 - val_loss: 0.0701 - val_accuracy: 0.9500
# Epoch 125/200
# 10/10 [==============================] - 45s 4s/step - loss: 0.0435 - accuracy: 0.9688 - val_loss: 0.1545 - val_accuracy: 0.9000
# Epoch 126/200
# 10/10 [==============================] - 39s 4s/step - loss: 0.0229 - accuracy: 0.9906 - val_loss: 1.3914 - val_accuracy: 0.6625
# Epoch 127/200
# 10/10 [==============================] - 36s 4s/step - loss: 0.0262 - accuracy: 0.9875 - val_loss: 0.1493 - val_accuracy: 0.9375
# Epoch 128/200
# 10/10 [==============================] - 36s 4s/step - loss: 0.0154 - accuracy: 0.9937 - val_loss: 0.8286 - val_accuracy: 0.6750
# Epoch 129/200
# 10/10 [==============================] - 38s 4s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.9663 - val_accuracy: 0.7625
# Epoch 130/200
# 10/10 [==============================] - 42s 4s/step - loss: 0.0138 - accuracy: 0.9906 - val_loss: 0.0694 - val_accuracy: 0.9500
# Epoch 131/200
# 10/10 [==============================] - 36s 3s/step - loss: 0.0067 - accuracy: 0.9969 - val_loss: 0.0393 - val_accuracy: 0.9750
# Epoch 132/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0745 - val_accuracy: 0.9500
# Epoch 133/200
# 10/10 [==============================] - 40s 4s/step - loss: 0.0142 - accuracy: 0.9937 - val_loss: 0.1620 - val_accuracy: 0.9375
# Epoch 134/200
# 10/10 [==============================] - 37s 4s/step - loss: 0.0069 - accuracy: 0.9969 - val_loss: 0.1149 - val_accuracy: 0.9500
# Epoch 135/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0052 - accuracy: 0.9969 - val_loss: 0.0370 - val_accuracy: 0.9750
# Epoch 136/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0065 - accuracy: 0.9969 - val_loss: 0.0588 - val_accuracy: 0.9750
# Epoch 137/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0159 - accuracy: 0.9906 - val_loss: 0.1355 - val_accuracy: 0.9625
# Epoch 138/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.1148 - val_accuracy: 0.9500
# Epoch 139/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9625
# Epoch 140/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0084 - accuracy: 0.9969 - val_loss: 0.0584 - val_accuracy: 0.9625
# Epoch 141/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0125 - accuracy: 0.9875 - val_loss: 0.0988 - val_accuracy: 0.9250
# Epoch 142/200
# 10/10 [==============================] - 32s 3s/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.1330 - val_accuracy: 0.9250
# Epoch 143/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.1214 - val_accuracy: 0.9250
# Epoch 144/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0098 - accuracy: 0.9937 - val_loss: 0.2047 - val_accuracy: 0.9250
# Epoch 145/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1070 - val_accuracy: 0.9500
# Epoch 146/200
# 10/10 [==============================] - 36s 4s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1414 - val_accuracy: 0.9250
# Epoch 147/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.2217 - val_accuracy: 0.8750
# Epoch 148/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0134 - accuracy: 0.9969 - val_loss: 0.3397 - val_accuracy: 0.8625
# Epoch 149/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0223 - accuracy: 0.9875 - val_loss: 0.5109 - val_accuracy: 0.8375
# Epoch 150/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0243 - accuracy: 0.9875 - val_loss: 0.3293 - val_accuracy: 0.8500
# Epoch 151/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0275 - accuracy: 0.9875 - val_loss: 0.0750 - val_accuracy: 0.9500
# Epoch 152/200
# 10/10 [==============================] - 36s 4s/step - loss: 0.0167 - accuracy: 0.9937 - val_loss: 0.0111 - val_accuracy: 0.9875
# Epoch 153/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0924 - val_accuracy: 0.9500
# Epoch 154/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0180 - accuracy: 0.9906 - val_loss: 0.7168 - val_accuracy: 0.7750
# Epoch 155/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0360 - accuracy: 0.9781 - val_loss: 0.5379 - val_accuracy: 0.8125
# Epoch 156/200
# 10/10 [==============================] - 32s 3s/step - loss: 0.0216 - accuracy: 0.9844 - val_loss: 0.5525 - val_accuracy: 0.8125
# Epoch 157/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0134 - accuracy: 0.9937 - val_loss: 0.5728 - val_accuracy: 0.8000
# Epoch 158/200
# 10/10 [==============================] - 32s 3s/step - loss: 0.0074 - accuracy: 0.9969 - val_loss: 0.2363 - val_accuracy: 0.8875
# Epoch 159/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0162 - accuracy: 0.9937 - val_loss: 0.2781 - val_accuracy: 0.8875
# Epoch 160/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.2951 - val_accuracy: 0.9000
# Epoch 161/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0279 - accuracy: 0.9812 - val_loss: 0.2229 - val_accuracy: 0.9000
# Epoch 162/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0123 - accuracy: 0.9906 - val_loss: 0.2849 - val_accuracy: 0.8875
# Epoch 163/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0134 - accuracy: 0.9937 - val_loss: 0.1546 - val_accuracy: 0.9125
# Epoch 164/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0252 - accuracy: 0.9906 - val_loss: 0.1402 - val_accuracy: 0.9375
# Epoch 165/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0096 - accuracy: 0.9969 - val_loss: 0.2369 - val_accuracy: 0.8875
# Epoch 166/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0203 - accuracy: 0.9937 - val_loss: 0.2712 - val_accuracy: 0.8500
# Epoch 167/200
# 10/10 [==============================] - 41s 4s/step - loss: 0.0104 - accuracy: 0.9937 - val_loss: 0.1791 - val_accuracy: 0.9000
# Epoch 168/200
# 10/10 [==============================] - 36s 4s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.1164 - val_accuracy: 0.9500
# Epoch 169/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0099 - accuracy: 0.9969 - val_loss: 0.1763 - val_accuracy: 0.9375
# Epoch 170/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0117 - accuracy: 0.9937 - val_loss: 0.2961 - val_accuracy: 0.9000
# Epoch 171/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0091 - accuracy: 0.9969 - val_loss: 0.2055 - val_accuracy: 0.9125
# Epoch 172/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2759 - val_accuracy: 0.8750
# Epoch 173/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0132 - accuracy: 0.9906 - val_loss: 0.2484 - val_accuracy: 0.8875
# Epoch 174/200
# 10/10 [==============================] - 36s 4s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2058 - val_accuracy: 0.9000
# Epoch 175/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0095 - accuracy: 0.9937 - val_loss: 0.1140 - val_accuracy: 0.9625
# Epoch 176/200
# 10/10 [==============================] - 33s 3s/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0936 - val_accuracy: 0.9625
# Epoch 177/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0057 - accuracy: 0.9969 - val_loss: 0.1080 - val_accuracy: 0.9625
# Epoch 178/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0328 - accuracy: 0.9781 - val_loss: 0.1173 - val_accuracy: 0.9250
# Epoch 179/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.3138 - val_accuracy: 0.8500
# Epoch 180/200
# 10/10 [==============================] - 36s 4s/step - loss: 0.0084 - accuracy: 0.9937 - val_loss: 0.1492 - val_accuracy: 0.9250
# Epoch 181/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0121 - accuracy: 0.9937 - val_loss: 0.7670 - val_accuracy: 0.7750
# Epoch 182/200
# 10/10 [==============================] - 42s 4s/step - loss: 0.0187 - accuracy: 0.9937 - val_loss: 0.2583 - val_accuracy: 0.8750
# Epoch 183/200
# 10/10 [==============================] - 37s 4s/step - loss: 0.0155 - accuracy: 0.9906 - val_loss: 0.0789 - val_accuracy: 0.9750
# Epoch 184/200
# 10/10 [==============================] - 36s 3s/step - loss: 0.0108 - accuracy: 0.9937 - val_loss: 0.0430 - val_accuracy: 0.9750
# Epoch 185/200
# 10/10 [==============================] - 38s 4s/step - loss: 0.0157 - accuracy: 0.9937 - val_loss: 0.1900 - val_accuracy: 0.9000
# Epoch 186/200
# 10/10 [==============================] - 37s 4s/step - loss: 0.0148 - accuracy: 0.9937 - val_loss: 0.2736 - val_accuracy: 0.8625
# Epoch 187/200
# 10/10 [==============================] - 37s 4s/step - loss: 0.0131 - accuracy: 0.9937 - val_loss: 0.1563 - val_accuracy: 0.9375
# Epoch 188/200
# 10/10 [==============================] - 37s 4s/step - loss: 0.0067 - accuracy: 0.9969 - val_loss: 0.1012 - val_accuracy: 0.9500
# Epoch 189/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0106 - accuracy: 0.9969 - val_loss: 0.1383 - val_accuracy: 0.9375
# Epoch 190/200
# 10/10 [==============================] - 38s 4s/step - loss: 0.0078 - accuracy: 0.9937 - val_loss: 0.0477 - val_accuracy: 0.9750
# Epoch 191/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0080 - accuracy: 0.9969 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.2157 - val_accuracy: 0.8875
# Epoch 193/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.3513 - val_accuracy: 0.8625
# Epoch 194/200
# 10/10 [==============================] - 37s 4s/step - loss: 0.0078 - accuracy: 0.9969 - val_loss: 0.1424 - val_accuracy: 0.9500
# Epoch 195/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9500
# Epoch 196/200
# 10/10 [==============================] - 37s 4s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0819 - val_accuracy: 0.9625
# Epoch 197/200
# 10/10 [==============================] - 36s 4s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9750
# Epoch 198/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0191 - val_accuracy: 0.9750
# Epoch 199/200
# 10/10 [==============================] - 35s 3s/step - loss: 0.0065 - accuracy: 0.9969 - val_loss: 0.0359 - val_accuracy: 0.9750
# Epoch 200/200
# 10/10 [==============================] - 34s 3s/step - loss: 0.0102 - accuracy: 0.9969 - val_loss: 0.0413 - val_accuracy: 0.9875
# 3/3 [==============================] - 1s 336ms/step - loss: 0.0413 - accuracy: 0.9875
# Test Accuracy: 98.7500011920929
